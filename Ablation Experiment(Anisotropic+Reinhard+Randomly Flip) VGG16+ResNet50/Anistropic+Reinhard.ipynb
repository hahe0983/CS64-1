# %%
import os
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# Anisotropic Diffusion Filter function
def anisodiff_color(img, niter=1, kappa=50, gamma=0.1, step=(1., 1.), option=1):
    img = img.astype('float32')
    imgout = img.copy()
    deltaS = np.zeros_like(imgout)
    deltaE = deltaS.copy()
    NS = deltaS.copy()
    EW = deltaS.copy()
    gS = np.ones_like(imgout)
    gE = gS.copy()

    for ii in range(niter):
        deltaS[:-1, :] = np.diff(imgout, axis=0)
        deltaE[:, :-1] = np.diff(imgout, axis=1)
        if option == 1:
            gS = np.exp(-(deltaS/kappa)**2.)/step[0]
            gE = np.exp(-(deltaE/kappa)**2.)/step[1]
        elif option == 2:
            gS = 1./(1.+(deltaS/kappa)**2.)/step[0]
            gE = 1./(1.+(deltaE/kappa)**2.)/step[1]
        E = gE * deltaE
        S = gS * deltaS
        NS[:] = S
        EW[:] = E
        NS[1:, :] -= S[:-1, :]
        EW[:, 1:] -= E[:, :-1]
        imgout += gamma * (NS + EW)

    return imgout

# Reinhard Stain Normalizer
def standardize_brightness(I):
    p = np.percentile(I, 90)
    return np.clip(I * 255.0 / p, 0, 255).astype(np.uint8)

def lab_split(I):
    I = cv.cvtColor(I, cv.COLOR_RGB2LAB)
    I = I.astype(np.float32)
    I1, I2, I3 = cv.split(I)
    I1 /= 2.55
    I2 -= 128.0
    I3 -= 128.0
    return I1, I2, I3

def merge_back(I1, I2, I3):
    I1 *= 2.55
    I2 += 128.0
    I3 += 128.0
    I = np.clip(cv.merge((I1, I2, I3)), 0, 255).astype(np.uint8)
    return cv.cvtColor(I, cv.COLOR_LAB2RGB)

def get_mean_std(I):
    I1, I2, I3 = lab_split(I)
    m1, sd1 = cv.meanStdDev(I1)
    m2, sd2 = cv.meanStdDev(I2)
    m3, sd3 = cv.meanStdDev(I3)
    means = m1, m2, m3
    stds = sd1, sd2, sd3
    return means, stds

class Normalizer:
    def __init__(self):
        self.target_means = None
        self.target_stds = None

    def fit(self, target):
        target = standardize_brightness(target)
        means, stds = get_mean_std(target)
        self.target_means = means
        self.target_stds = stds

    def transform(self, I):
        I = standardize_brightness(I)
        I1, I2, I3 = lab_split(I)
        means, stds = get_mean_std(I)
        norm1 = ((I1 - means[0]) * (self.target_stds[0] / stds[0])) + self.target_means[0]
        norm2 = ((I2 - means[1]) * (self.target_stds[1] / stds[1])) + self.target_means[1]
        norm3 = ((I3 - means[2]) * (self.target_stds[2] / stds[2])) + self.target_means[2]
        return merge_back(norm1, norm2, norm3)

# Directories setup
input_dir = './demo_datasets_week8'  # Your input dataset directory
output_dir = './Demo_Dataset(anistropic+reinhard)'  # Directory for processed images

# Create output directory if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Initialize Normalizer with a target image for stain normalization
target_image_path = './target_image.jpg'  # Replace with your actual target image path
target_image = cv.imread(target_image_path)

# Check if the target image loaded successfully
if target_image is None:
    raise ValueError(f"Failed to load target image from {target_image_path}. Check the path and file format.")

target_image = cv.cvtColor(target_image, cv.COLOR_BGR2RGB)

# Fit normalizer with the target image
normalizer = Normalizer()
normalizer.fit(target_image)

# Define supported image extensions including .tif and .tiff
supported_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.tif')

# Process each class folder and each image
for class_folder in os.listdir(input_dir):
    class_path = os.path.join(input_dir, class_folder)
    if not os.path.isdir(class_path):
        continue
    
    # Create corresponding class folder in the output directory
    output_class_path = os.path.join(output_dir, class_folder)
    if not os.path.exists(output_class_path):
        os.makedirs(output_class_path)
    
    # Process each image in the class folder
    for image_name in os.listdir(class_path):
        image_path = os.path.join(class_path, image_name)
        
        # Check if the file is an image by extension
        if not image_name.lower().endswith(supported_extensions):
            print(f"Skipping non-image file: {image_path}")
            continue
        
        # Load the image
        image = cv.imread(image_path, cv.IMREAD_UNCHANGED)
        if image is None:
            print(f"Failed to load image: {image_path}")
            continue
        
        # Convert to RGB if not already in correct format
        if len(image.shape) == 2 or image.shape[2] == 1:  # Handle grayscale images
            image = cv.cvtColor(image, cv.COLOR_GRAY2RGB)
        elif image.shape[2] == 4:  # Handle images with alpha channel
            image = cv.cvtColor(image, cv.COLOR_BGRA2RGB)
        else:
            image = cv.cvtColor(image, cv.COLOR_BGR2RGB)
        
        # Apply Anisotropic Diffusion
        diffused_image = anisodiff_color(image, niter=10, kappa=100, gamma=0.1, step=(1., 1.), option=1)
        
        # Apply Reinhard Stain Normalization
        normalized_image = normalizer.transform(diffused_image)
        
        # Convert back to BGR for saving
        normalized_image_bgr = cv.cvtColor(normalized_image, cv.COLOR_RGB2BGR)
        
        # Save the processed image
        output_image_path = os.path.join(output_class_path, image_name)
        cv.imwrite(output_image_path, normalized_image_bgr)

        print(f"Processed and saved: {output_image_path}")
# Out:
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\1015_CRC-Prim-HE-10_020.tif_Row_601_Col_601.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\1040C_CRC-Prim-HE-05_032.tif_Row_1051_Col_2101.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\1050A_CRC-Prim-HE-03_012.tif_Row_301_Col_1351.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\109EF_CRC-Prim-HE-03_012.tif_Row_3151_Col_901.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\10C21_CRC-Prim-HE-05_032.tif_Row_1201_Col_3901.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\110E3_CRC-Prim-HE-07.tif_Row_301_Col_3901.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\11472_CRC-Prim-HE-07.tif_Row_1201_Col_2701.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\1157_CRC-Prim-HE-05_032.tif_Row_1051_Col_2701.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\11744_CRC-Prim-HE-07.tif_Row_1_Col_3301.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\1174E_CRC-Prim-HE-03_012.tif_Row_901_Col_901.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\1199B_CRC-Prim-HE-07.tif_Row_751_Col_2701.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\11CFA_CRC-Prim-HE-05_032.tif_Row_901_Col_4951.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\121F7_CRC-Prim-HE-05_032.tif_Row_1351_Col_601.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\123A0_CRC-Prim-HE-03_012.tif_Row_3151_Col_751.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\127AE_CRC-Prim-HE-03_012.tif_Row_2251_Col_901.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\12949_CRC-Prim-HE-03_012.tif_Row_2701_Col_1651.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\12C98_CRC-Prim-HE-06_004.tif_Row_2401_Col_1.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\12F9D_CRC-Prim-HE-03_012.tif_Row_3001_Col_451.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\1301C_CRC-Prim-HE-05_032.tif_Row_1201_Col_901.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\13348_CRC-Prim-HE-10_020.tif_Row_1_Col_451.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\13A2D_CRC-Prim-HE-03_012.tif_Row_2251_Col_1.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\1489D_CRC-Prim-HE-05_032.tif_Row_1201_Col_1351.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\14A0B_CRC-Prim-HE-03_012.tif_Row_451_Col_2851.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\14DEA_CRC-Prim-HE-07.tif_Row_751_Col_2851.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\1522E_CRC-Prim-HE-07_035.tif_Row_151_Col_151.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\152FB_CRC-Prim-HE-06_004.tif_Row_2551_Col_2701.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\153A3_CRC-Prim-HE-03_012.tif_Row_3901_Col_1201.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\15493_CRC-Prim-HE-05_032.tif_Row_151_Col_451.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\15793_CRC-Prim-HE-03_012.tif_Row_1351_Col_2401.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\15B6D_CRC-Prim-HE-06_004.tif_Row_1801_Col_1.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\15B72_CRC-Prim-HE-03_012.tif_Row_2251_Col_2401.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\15E6C_CRC-Prim-HE-05_032.tif_Row_1201_Col_3001.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\1602A_CRC-Prim-HE-07.tif_Row_451_Col_3001.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\16031_CRC-Prim-HE-03_012.tif_Row_751_Col_2701.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\160A4_CRC-Prim-HE-05_032.tif_Row_1051_Col_4951.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\1626D_CRC-Prim-HE-10_020.tif_Row_601_Col_751.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\163B8_CRC-Prim-HE-03_012.tif_Row_301_Col_601.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\16997_CRC-Prim-HE-03_012.tif_Row_3001_Col_151.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\16DBD_CRC-Prim-HE-03_012.tif_Row_451_Col_2101.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\16E6A_CRC-Prim-HE-06_004.tif_Row_1501_Col_1051.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\16F5E_CRC-Prim-HE-03_012.tif_Row_751_Col_2851.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\16FD8_CRC-Prim-HE-04_036.tif_Row_601_Col_1351.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-AAEARKHL.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-AALYKARR.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-AAYEICFW.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-ACILDKQP.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-ACPQAYSY.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-ACQLPFFH.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-ACSMGLCP.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-ADTCIQPN.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-AECCHRVS.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-AEKSWYMK.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-AFARTQDV.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-AFEFVHHV.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-AFWNMCYG.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-AFYDCDRG.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-AGCGMKKT.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-AGCKYQNF.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-AGKYEVEN.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-AGVSSDNF.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-AGYNYLHH.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-AHELLKML.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-AHPMIECS.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-AIGCHQSV.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-AKASWKKK.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-AKFEGFRR.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-AKPRYNPQ.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-AKQYSCNC.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-ALHAFTHA.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-ALIEALNQ.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-AMGMQIGV.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-AMNSSCIP.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-AMQSDAWM.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-ANCAATCL.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-ANCIRKVK.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-ANEWKNLG.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-ANPMHWPP.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-ANPTKKGY.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-APICTFLI.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-APTVPTSQ.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-AQEADWSS.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-ARENVADV.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-ATIMKLIL.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-ATNGGAKP.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-ATWQSLWT.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-AVMGPEGD.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-AVRQLTLV.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-AWASPLYD.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-AYFRWKVF.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-CAKNKIAM.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-CAMVGAPK.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-CAVEGDLV.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-CCAWVTSV.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-CCDWPSCI.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-CCQACGRE.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-CCRFEMKC.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-CDDNVVRR.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-CDERHCTS.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-CDFAHNIS.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-CDKVRIKE.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-CEEQRIVC.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-CELWEGVR.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-CETGFSCF.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-CFADKNRI.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-CFDYTLSA.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-CFNILSVM.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-CFTSKAPE.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-CFYLMYEG.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-CHAEAISW.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-CHLKEDLY.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-CHPVRDCA.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-CHVVKQND.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-CIAHMPHE.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-CIGQQRKK.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-CIQQIRWY.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-CIVMYVVW.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-CKEDGSWY.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-CKESDYQR.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-CKLDPGDK.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-CKTWRDLQ.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-CLTIFKKL.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-CMMCMEYA.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-CMQQHQMD.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-CNEEEQDM.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-CNKTAAVC.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-CNPAIQPW.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-CNSTNNPQ.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-CNYTIPPP.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-CPACAEET.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-CPDIMRYT.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-CPMQTGNF.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-CPNPFKGR.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-CQKASPWW.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-CQQKVAET.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-CRAEVLVQ.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-CRCHQSAT.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-CREELVED.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-CRGTTMFL.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-CRNDMNDV.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-CRQRNNIP.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-CRREAYTS.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-CRTQYNWY.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-CSFIFEAT.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-CSWMREPT.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-CTNDYGYK.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-CVCMCIDH.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-CWHNYSQF.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-CWLAMGLS.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-CWMSKTDD.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-CWSHKNQD.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-CWWALWCC.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-CYESDRQL.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-CYFDGEKC.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-CYMFCSAS.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-CYSSQWFA.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-CYTSNRSY.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-CYVAKIYT.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-DAADQMPI.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-DAGDINQQ.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-DAHDSARV.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-DCEPSCCN.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-DCFCRNPP.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-DCHTMQTM.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-DDFYCIEY.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-DDIWQSMD.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-DDLGLSDC.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-DDLMQSDT.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-DDRSTKPQ.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-DDVICCLV.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-DEHGFYHH.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-DETQRWTR.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-DEVGLFTM.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-DEVIPILT.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-DEWCIWWA.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-DFAGIKLN.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-DFHPMEVN.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-DFVCCLGN.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-DGADNWCT.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-DHPEMRPW.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-DHSVNFYD.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-DHVSICWY.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-DIADYSNS.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-DIAPLLTK.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-DIAYKKYN.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-DIFPEYPH.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-DINEYVCF.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-DIYLQLAD.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-DKQASKID.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-DKRCKILQ.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-DKVPRVLG.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-DLCMEMNW.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-DLFIVDYM.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-DMMHEYRY.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-DMPTNGNN.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-DMQVYAHY.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-DMSDMYHP.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-DNCKEMLH.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-DNCSPFCA.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-DNKIQDTP.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-DNLHERIH.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-DPDLANIN.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-DPVQDQHV.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-DQCKHSYG.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-DQEMNIEC.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-DQLEMRIF.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-DQRIAIKV.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-DSDVECCD.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-DSEHGGIT.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-DSPDPQEH.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-DTHHHLKE.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-DTQPTTPT.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-DVKQYTAN.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-DWFMCLTQ.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-DWHNYHFP.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-DWLDLFKK.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-DWMVSFIE.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-DYRGQTRK.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-DYTKHLGT.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-EAMCETVL.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-EAVRCRWR.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-EAVSHNTP.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-EAWIITRQ.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-ECCFFPRT.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-ECIPFVDD.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-ECKTKMCK.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-ECTIGARI.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-ECVVQWHH.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-EDAPTWTL.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-EDQGYAGV.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-EDWRALYD.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-EECLYTFY.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-EEHINGTP.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-EEIPCMVE.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-EELINHLL.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-EFMWNVMC.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-EFTQLNLL.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-EGCCDIAR.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-EGCPMCQV.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-EGFRHDVL.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-EGGNTFCA.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-EGHMEDTQ.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-EGILRTEF.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-EGSDRCYC.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-EGSSGHAI.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-EHHSQARC.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-EHMTWMMA.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-EHNFLLWK.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-EIIYPYRT.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-EIQQMHRY.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-EIVNEHVI.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-EKAYCETS.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-EKPDLWEI.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-ELPSMPSD.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-EMLKDPQM.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-EMRVDVGI.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-EMWEGEKH.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-EMYVPCMF.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-ENANVDAK.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-ENKTYGVD.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-EPARCCVN.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-EPIENDWM.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-EPIREDAE.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-EPTRSNAS.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-EPWMKCKY.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-EQIDRKYW.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-EQTALNNS.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-EQTTGDQA.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-ERFFVPFN.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-ERGFYIIW.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-ERIYNTWK.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-ERMPGNER.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-ERRHDCKA.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-ERVRVNDY.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-ESDCMHPE.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-ESNQVTSD.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-ETQRKPES.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-EVDQQVFQ.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-EVPQITCG.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-EWNFDEIS.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-EWYWALHH.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-EYGIIAED.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-EYGMPVCF.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-EYLEIRYY.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-FAPRLIEH.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-FASWWKTR.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-FCGGLHDE.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-FCIDVFNM.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-FCIRLAGA.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-FDAEYDHW.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-FDIQPTDK.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-FECRHFVP.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-FECRKNEI.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-FEGFGEGD.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-FEHWHRPH.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-FELEMREQ.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-FEQDRLMD.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-FEWMPQIL.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-FFITWFCF.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-FFQFYEIE.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-FFSEKLYE.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-FGAWLHVE.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-FGCNEGDK.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-FGLLQQNC.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-FHGTKSGG.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-FHHADYQE.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-FHSALILL.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-FIGPAVLN.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-FIIQAQLT.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-FIPHCSSY.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-FITHSMAN.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-FIYSGESN.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-FKRQLVII.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-FMQMQVSL.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-FPPATISD.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-FPRSRKPI.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-FPTKPWAQ.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-FQVFGMNH.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-FRIAMTVT.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-FRSCKRAQ.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-FRTGWWAA.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-FSFMCWQD.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-FSKEHLRP.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-FSPQNKED.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-FSWLEWKL.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-FVCLALCY.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-FVFYVDWY.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-FVHKIGGV.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-FVKQANMH.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-FWGTPNKT.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-FWPTSTMM.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-FYVWDEWF.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-GAADWLQA.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-GACCWTQV.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-GAFRHCHE.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-GAGSWMLM.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-GANMPSGS.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-GCELRELC.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-GCRQTFME.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-GCVGYATN.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-GDSHSAGK.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-GEAGWQEF.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-GFIPKTCV.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-GFRNYHHP.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-GFVSGAMP.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-GGHKASRL.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-GHITNVAI.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-GHSLGERM.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-GIQCNWPY.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-GKWWTYTW.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-GMIETQPP.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-GMYRRTKF.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-GNTQNVHK.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-GNWKLNTV.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-GPPMMWDH.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-GPQYLHGE.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-GPTIYRHW.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-GPWNDDHL.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-GQAQVPKL.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-GQHTHDVS.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-GRATAAGT.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-GRCYFVCK.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-GRHMCMAE.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-GRKATISV.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-GRKPRNIM.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-GSLEHGDM.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-GSYICRDL.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-GTLNEWHG.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-GVDCAQTK.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-GVDWGGGG.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-GVILYIKF.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-GVSVCPHE.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-GWERYFKF.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-GWFLHYIK.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-GWKCHIAW.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-GWPDYGVE.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-HAEKWTNQ.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-HALAGHEC.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-HALVYAHH.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-HATDTALI.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-HCKEEDNS.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-HCNDKPCE.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-HCNVVCRD.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-HCRGGFSS.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-HCTMECNW.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-HCWRRCHC.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-HDHFINGG.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-HDMPEHHA.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-HDWLGVHC.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-HEAWNITH.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-HETCQDLE.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-HEVAFILL.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-HFCYQFCD.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-HGFQNDVR.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-HGNMVNWA.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-HGQLHDIY.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-HGYEYFQW.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-HILDQVQL.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-HKEKPRFA.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-HKMRVCNE.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-HLQQLDNN.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-HLTDRLKS.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-HMSSFWWW.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-HNYIWPSF.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-HPLHHKHC.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-HPSLCFFV.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-HQARQVNR.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-HQNTFFCH.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-HRGQMHWT.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-HSKDIPKF.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-HSTNQDGN.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-HTFMQDIN.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-HWAVIIPC.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-HWDETTVQ.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-HWFWNEES.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-HWHTDTVV.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-HYCKPMWY.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-HYFPEVKM.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-HYHFPMTK.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-HYQVMSFI.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-HYSAKYGN.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-HYWGFHMM.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-IACCLRLN.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-IAKGIMAC.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-ICEHVPIN.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-ICLLESDR.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-ICTEYPWL.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-ICYFNAVK.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-IDERIDYK.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-IDKNHMGR.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-IECMYWIE.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-IEKMSNFC.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-IEQTPHSV.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-IETYWEEW.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-IEVCSVVN.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-IEYRWIQM.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-IFPKDKVE.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-IFVVYHTT.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-IGRFVGVI.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-IGYAKSMA.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-IGYEVADT.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-IHCWKMGV.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-IHFVPEII.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-IHHNYMWG.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-IHKLRISR.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-IHNDTADR.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-IIDGPVWD.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-IIYKQDHW.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-IKGCCCKM.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-IKWTMAIE.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-ILLPEAYM.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-IMDKKAYP.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-IMIVSFMN.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-IMLRFEER.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-IMRQIEKG.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-INSEELHW.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-INTHSCPK.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-INVWDPCV.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-IPKARCFA.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-IPLLYKKW.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-IPSQGFDP.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-IQFECPMK.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-IQIDHCQS.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-IQTWSHCI.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-IRIVTTKE.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-ISELPFIL.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-ISLSESMA.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-ITCPPAGH.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-ITQHEHVV.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-IWRDCLGF.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-IYDVATSR.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-IYKQTVAK.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-KAMRELYA.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-KANIWPVR.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-KARHLYKH.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-KDACGKYI.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-KDFGMFPV.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-KDHHENWW.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-KDLTREGW.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-KEDYWQWK.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-KELKAGGH.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-KEQMQEFI.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-KFVDSVYD.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-KGPKYAYW.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-KHKIYAFC.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-KHTTSKGC.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-KHWVIMKV.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-KIFARSKF.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-KIFVVVEI.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-KINIADPW.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-KIRLLPIG.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-KKLRSFTW.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-KKQTCWIE.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-KKTRHTNT.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-KKTVLGYM.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-KLLRPIGG.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-KNESNNYN.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-KNGHVINK.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-KPHESSWE.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-KPNEYYPD.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-KPYFPSCE.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-KQCRKGLS.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-KRCIDRVN.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-KRDLEDTG.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-KRLPGWSQ.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-KRLTHQKR.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-KSEVHSEN.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-KSFCFCHY.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-KSNEHLQK.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-KSTITCQP.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-KVVKCDDN.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-KWIGNVTM.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-KWRQEMRR.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-KYHDPEKV.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-LAFGIYET.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-LANMVCQD.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-LAWYGFSP.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-LCAAQAMQ.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-LCNVYVQP.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-LCQRGHTA.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-LCWCEWTH.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-LDDLPILF.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-LDIIQNGQ.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-LEGKALME.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-LEGKKVDT.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-LEHCEFFA.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-LEQCPRIL.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-LFYCPMMH.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-LGLGIQVC.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-LHEIPISL.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-LHGHICQK.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-LHKGIYMG.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-LHRVCYRC.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-LIAVPTDK.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-LIEPPQTR.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-LISAYLKL.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-LKEAKPWQ.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-LLSLRMTA.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-LLSLYITN.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-LLTSIDCQ.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-LMWKEYLP.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-LNGTSAGI.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-LNNYRVHN.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-LPCGCKII.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-LPIMSRFN.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-LPLVNEGT.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-LPTWQRVR.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-LRDYVGAT.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-LREYTYWT.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-LRKNANYP.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-LRQASPRP.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-LSCEEQYD.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-LSMNMWND.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-LSPPYYVP.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-LSYGFQGT.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-LTREGVCT.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-LVMCYVCI.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-LWGDFTNI.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-LYFFQTIS.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-LYNGMYKT.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-LYPGPLSL.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-LYPNHKTA.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-MAFQTQGI.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-MAKCEWNP.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-MCCHTWCA.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-MCCWEQMA.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-MCWDGELG.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-MDAYTHIF.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-MEAFCWWR.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-MEFMVQED.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-MENHATDR.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-MEPYWLVC.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-MEVFMMTT.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-MFMRYWTH.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-MFPSFCHN.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-MGIWGHEK.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-MGNYYYIE.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-MGSQWYKQ.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-MHAKLYFL.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-MHCDMSFT.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-MHMMPICR.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-MHVYYKFQ.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-MKTSQFNK.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-MKWHDNNP.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-MLIWFFQA.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-MLNTYKIM.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-MLRALAKM.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-MMAFYGCN.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-MMECICGE.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-MMEFMKPY.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-MNFHEVSH.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-MNVMKGDM.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-MPMDHNED.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-MPPSEVTW.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-MQGWDLGG.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-MQYRLVIM.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-MRIWFMCD.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-MSHCLCAF.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\ADI\ADI-MSPTTQCT.tif
# ...
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-RGTCAGRK.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-RGYEFSSG.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-RIPAVDAY.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-RIVYHSMP.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-RKIVRFRN.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-RKSWRVTK.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-RLFMDAPG.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-RLKTPPIG.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-RMTGAWRN.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-RMTQSCHA.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-RPYTIRTD.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-RQVPFGYW.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-RRSERNPF.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-RSHTCMAI.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-RSLMFDMK.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-RTCDPQVY.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-RTHRGKSQ.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-RTLCLPGV.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-RVYCTQKI.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-RVYGHNPG.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-RWHWTWKA.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-RYEQCIEP.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-RYLNAWPW.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-RYQDCQAY.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-RYWSMVWI.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-SAAIMMCG.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-SAGWSSHN.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-SAHYEIAY.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-SCEISFAG.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-SCPGKLHN.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-SDAQKENR.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-SDCTENQI.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-SDRCVWCI.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-SEALRMPC.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-SEDNYEWM.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-SENSYVQL.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-SEQCDYHK.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-SFSHPDPW.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-SGQDDHHD.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-SGRRLKNC.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-SHLHDWKF.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-SHNLYWWC.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-SHRYIWMA.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-SIHQVVTY.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-SIQNVQIS.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-SKVFKTIN.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-SLHVSILN.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-SLIRFVRS.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-SMYMELNF.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-SNATKTFW.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-SPFSGMSH.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-SPLCTHVC.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-SQCACRYK.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-SQDSVDPI.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-SQDTIICQ.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-SQPERIDN.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-SQQCQPDP.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-SQWYMNSN.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-SQYLPWCS.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-SSDPKLIG.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-SSRGYCSC.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-SVIVSNIT.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-SVQGLKAG.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-SWCLDVKQ.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-SYNTDGHQ.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-SYTRRVMY.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-TAYLSLMI.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-TCSRELFN.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-TETNPCAY.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-THFHSPNT.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-TIELLPSM.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-TITLRDNF.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-TITTAKER.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-TIWVIYAQ.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-TLMFQATF.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-TLMNHVMI.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-TMKHLWLM.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-TMRQATNA.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-TNIREYQD.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-TPPDKWSQ.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-TPTTQVSC.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-TQACGMTL.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-TQAIEKFG.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-TQKDTRFL.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-TSMTKRMD.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-TTNRFAYE.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-TTQSKSLS.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-TTVAGIAT.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-TVCGKDVI.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-TWCTDFRM.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-VADYTNTV.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-VAQQPIDN.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-VAYIFTKH.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-VCFCFCYT.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-VCQNDRED.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-VCWGMSKH.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-VDGWMINV.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-VDNDKFCQ.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-VDQLWEDK.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-VDSLHNSN.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-VDYPFRWC.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-VEIQCVLH.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-VEPNETWL.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-VFRPSKNV.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-VGDWQPRT.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-VHIDGHGG.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-VIDIQHHY.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-VIMTFFAD.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-VKYFESEG.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-VLTDYMWK.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-VMESNKIL.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-VMPIWGWL.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-VNGVSVIY.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-VPNDRVPW.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-VPNHDPGG.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-VPPTHRHH.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-VPSWFNRH.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-VRTFQFEG.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-VRVMRTES.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-VSENPSMS.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-VSKFKGKI.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-VSRYTGPR.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-VTDCSIAM.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-VVEMNVTW.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-VWICRDTR.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-VWWSDSTA.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-VYGEAFND.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-WAELHYKM.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-WCKNELIR.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-WDDAVYAK.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-WDKEVKRE.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-WDRDDTIT.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-WFCCQQKI.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-WFILGPTM.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-WGATCDLC.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-WGGMVSHG.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-WHMGFIYN.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-WHRNYQWP.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-WIKAVAEN.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-WITHWLYA.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-WIYINRIY.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-WLFWCPRI.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-WLGCGQMC.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-WLYKAWDP.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-WMLYHGSE.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-WMRGFNIW.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-WMTPHVLF.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-WNFRNQYC.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-WNMVTHTE.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-WNPVRVVC.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-WNTRHTWS.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-WQGVGFEV.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-WQLDFQAT.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-WQYSFTAM.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-WSCQQFTR.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-WSVLPRYL.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-WTIDCRYE.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-WTRLSFIT.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-WTYDDTEG.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-WVFVWIMD.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-WVKQFELS.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-WWGMNGIY.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-WWNRFVAP.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-WWVNLKRS.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-WYEVFSCQ.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-WYKFRQAH.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-YAFVAPTG.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-YAKYKWCM.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-YAQWNGSD.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-YAVWITQP.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-YCDWISWK.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-YCNIWQGP.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-YCQFPRWT.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-YCRMARCA.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-YDCTKVHF.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-YDVHFEMT.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-YEAMDYHD.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-YETCYFAR.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-YFDLRLLR.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-YFHSQDSH.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-YFQQTMFE.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-YFQVFGHW.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-YGAPLFIE.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-YGQGYEGR.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-YHKPFYTM.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-YHWLMYND.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-YIEGVFEI.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-YIYVCGKQ.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-YKFQAAWL.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-YKHDFNVE.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-YLAVRGTV.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-YLDHDHKK.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-YLIYYSGP.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-YLTPIWTR.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-YLWCRHCL.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-YMVKLYEQ.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-YNNVMWSV.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-YPAHTAAA.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-YPLTGGLG.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-YQSIDIPN.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-YSCDFLMN.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-YVTTEEFY.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-YVVNSMTN.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-YYSSGWQM.tif
# Processed and saved: ./Demo_Dataset(anistropic+reinhard)\TUM\TUM-YYWMMMNW.tif

# %%
import os

# Define the path to the processed dataset directory
output_dir = './Demo_Dataset(anistropic+reinhard)'

# Initialize a dictionary to hold the counts for each class
class_counts = {}

# Iterate through each class folder in the output directory
for class_folder in os.listdir(output_dir):
    class_path = os.path.join(output_dir, class_folder)
    
    # Check if it is a directory
    if os.path.isdir(class_path):
        # Count the number of image files in the class folder
        num_images = len([img for img in os.listdir(class_path) if img.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.tif'))])
        class_counts[class_folder] = num_images

# Print the counts for each class
for class_name, count in class_counts.items():
    print(f"Class '{class_name}': {count} images")
# Out:
# Class '.ipynb_checkpoints': 0 images
# Class 'ADI': 1000 images
# Class 'DEBRIS_MUCUS': 1000 images
# Class 'LYM': 1000 images
# Class 'MUSC_STROMA': 1000 images
# Class 'NORM': 1000 images
# Class 'TUM': 1000 images
