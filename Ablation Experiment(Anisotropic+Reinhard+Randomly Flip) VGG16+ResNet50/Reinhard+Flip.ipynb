# %%
import os
import cv2 as cv
import numpy as np
import random

# Anisotropic Diffusion function, Reinhard Stain Normalizer class, and all required functions remain the same.

# Directories
input_dir = './demo_datasets_week8'
output_dir = './Demo_Dataset(reinhard+flip)'

if not os.path.exists(output_dir):
    os.makedirs(output_dir)
    
# Reinhard Stain Normalizer
def standardize_brightness(I):
    p = np.percentile(I, 90)
    return np.clip(I * 255.0 / p, 0, 255).astype(np.uint8)

def lab_split(I):
    I = cv.cvtColor(I, cv.COLOR_RGB2LAB)
    I = I.astype(np.float32)
    I1, I2, I3 = cv.split(I)
    I1 /= 2.55
    I2 -= 128.0
    I3 -= 128.0
    return I1, I2, I3

def merge_back(I1, I2, I3):
    I1 *= 2.55
    I2 += 128.0
    I3 += 128.0
    I = np.clip(cv.merge((I1, I2, I3)), 0, 255).astype(np.uint8)
    return cv.cvtColor(I, cv.COLOR_LAB2RGB)

def get_mean_std(I):
    I1, I2, I3 = lab_split(I)
    m1, sd1 = cv.meanStdDev(I1)
    m2, sd2 = cv.meanStdDev(I2)
    m3, sd3 = cv.meanStdDev(I3)
    means = m1, m2, m3
    stds = sd1, sd2, sd3
    return means, stds

class Normalizer:
    def __init__(self):
        self.target_means = None
        self.target_stds = None

    def fit(self, target):
        target = standardize_brightness(target)
        means, stds = get_mean_std(target)
        self.target_means = means
        self.target_stds = stds

    def transform(self, I):
        I = standardize_brightness(I)
        I1, I2, I3 = lab_split(I)
        means, stds = get_mean_std(I)
        norm1 = ((I1 - means[0]) * (self.target_stds[0] / stds[0])) + self.target_means[0]
        norm2 = ((I2 - means[1]) * (self.target_stds[1] / stds[1])) + self.target_means[1]
        norm3 = ((I3 - means[2]) * (self.target_stds[2] / stds[2])) + self.target_means[2]
        return merge_back(norm1, norm2, norm3)
        
normalizer = Normalizer()
target_image_path = './target_image.jpg'
target_image = cv.imread(target_image_path, cv.IMREAD_COLOR)

if target_image is None:
    raise FileNotFoundError(f"Target image not found at path: {target_image_path}")

normalizer.fit(cv.cvtColor(target_image, cv.COLOR_BGR2RGB))

# Process each class folder within the dataset directory
for class_folder in os.listdir(input_dir):
    class_path = os.path.join(input_dir, class_folder)
    
    if not os.path.isdir(class_path):
        print(f"Skipping non-directory entry: {class_path}")
        continue
    
    # Make sure the output directory for the class exists
    output_class_path = os.path.join(output_dir, class_folder)
    if not os.path.exists(output_class_path):
        os.makedirs(output_class_path)
    
    for image_name in os.listdir(class_path):
        image_path = os.path.join(class_path, image_name)
        image = cv.imread(image_path, cv.IMREAD_COLOR)
        
        if image is None:
            print(f"Failed to load image: {image_path}")
            continue
        
        image_rgb = cv.cvtColor(image, cv.COLOR_BGR2RGB)
        
        # Apply Anisotropic Diffusion and Reinhard Stain Normalization
        #diffused_image = anisodiff_color(image_rgb, niter=10, kappa=100, gamma=0.1, step=(1., 1.), option=1)
        normalized_image = normalizer.transform(image_rgb)
        
        # Randomly decide to apply a horizontal flip
        if random.random() < 0.1:
            final_image = cv.flip(normalized_image, 1)  # Mirror flip horizontally
        else:
            final_image = normalized_image
        
        # Save the final image
        output_image_path = os.path.join(output_class_path, image_name)
        cv.imwrite(output_image_path, cv.cvtColor(final_image, cv.COLOR_RGB2BGR))
        print(f"Processed and saved: {output_image_path}")
# Out:
# Processed and saved: ./Demo_Dataset(reinhard+flip)\ADI\
.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-TQACGMTL.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-TQAIEKFG.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-TQKDTRFL.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-TSMTKRMD.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-TTNRFAYE.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-TTQSKSLS.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-TTVAGIAT.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-TVCGKDVI.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-TWCTDFRM.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-VADYTNTV.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-VAQQPIDN.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-VAYIFTKH.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-VCFCFCYT.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-VCQNDRED.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-VCWGMSKH.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-VDGWMINV.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-VDNDKFCQ.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-VDQLWEDK.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-VDSLHNSN.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-VDYPFRWC.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-VEIQCVLH.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-VEPNETWL.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-VFRPSKNV.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-VGDWQPRT.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-VHIDGHGG.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-VIDIQHHY.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-VIMTFFAD.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-VKYFESEG.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-VLTDYMWK.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-VMESNKIL.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-VMPIWGWL.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-VNGVSVIY.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-VPNDRVPW.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-VPNHDPGG.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-VPPTHRHH.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-VPSWFNRH.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-VRTFQFEG.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-VRVMRTES.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-VSENPSMS.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-VSKFKGKI.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-VSRYTGPR.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-VTDCSIAM.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-VVEMNVTW.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-VWICRDTR.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-VWWSDSTA.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-VYGEAFND.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-WAELHYKM.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-WCKNELIR.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-WDDAVYAK.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-WDKEVKRE.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-WDRDDTIT.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-WFCCQQKI.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-WFILGPTM.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-WGATCDLC.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-WGGMVSHG.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-WHMGFIYN.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-WHRNYQWP.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-WIKAVAEN.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-WITHWLYA.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-WIYINRIY.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-WLFWCPRI.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-WLGCGQMC.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-WLYKAWDP.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-WMLYHGSE.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-WMRGFNIW.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-WMTPHVLF.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-WNFRNQYC.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-WNMVTHTE.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-WNPVRVVC.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-WNTRHTWS.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-WQGVGFEV.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-WQLDFQAT.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-WQYSFTAM.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-WSCQQFTR.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-WSVLPRYL.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-WTIDCRYE.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-WTRLSFIT.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-WTYDDTEG.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-WVFVWIMD.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-WVKQFELS.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-WWGMNGIY.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-WWNRFVAP.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-WWVNLKRS.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-WYEVFSCQ.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-WYKFRQAH.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-YAFVAPTG.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-YAKYKWCM.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-YAQWNGSD.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-YAVWITQP.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-YCDWISWK.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-YCNIWQGP.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-YCQFPRWT.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-YCRMARCA.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-YDCTKVHF.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-YDVHFEMT.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-YEAMDYHD.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-YETCYFAR.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-YFDLRLLR.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-YFHSQDSH.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-YFQQTMFE.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-YFQVFGHW.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-YGAPLFIE.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-YGQGYEGR.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-YHKPFYTM.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-YHWLMYND.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-YIEGVFEI.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-YIYVCGKQ.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-YKFQAAWL.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-YKHDFNVE.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-YLAVRGTV.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-YLDHDHKK.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-YLIYYSGP.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-YLTPIWTR.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-YLWCRHCL.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-YMVKLYEQ.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-YNNVMWSV.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-YPAHTAAA.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-YPLTGGLG.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-YQSIDIPN.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-YSCDFLMN.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-YVTTEEFY.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-YVVNSMTN.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-YYSSGWQM.tif
# Processed and saved: ./Demo_Dataset(reinhard+flip)\TUM\TUM-YYWMMMNW.tif

# %%
import os

# Define the path to the processed dataset directory
output_dir = './Demo_Dataset(reinhard+flip)'

# Initialize a dictionary to hold the counts for each class
class_counts = {}

# Iterate through each class folder in the output directory
for class_folder in os.listdir(output_dir):
    class_path = os.path.join(output_dir, class_folder)
    
    # Check if it is a directory
    if os.path.isdir(class_path):
        # Count the number of image files in the class folder
        num_images = len([img for img in os.listdir(class_path) if img.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.tif'))])
        class_counts[class_folder] = num_images

# Print the counts for each class
for class_name, count in class_counts.items():
    print(f"Class '{class_name}': {count} images")
# Out:
# Class 'ADI': 1000 images
# Class 'DEBRIS_MUCUS': 1000 images
# Class 'LYM': 1000 images
# Class 'MUSC_STROMA': 1000 images
# Class 'NORM': 1000 images
# Class 'TUM': 1000 images
