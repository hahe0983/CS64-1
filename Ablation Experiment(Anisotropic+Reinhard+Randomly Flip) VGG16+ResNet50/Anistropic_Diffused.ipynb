# %%
import os
import cv2 as cv
import numpy as np

# Anisotropic Diffusion Filter function
def anisodiff_color(img, niter=1, kappa=50, gamma=0.1, step=(1., 1.), option=1):
    img = img.astype('float32')
    imgout = img.copy()
    deltaS = np.zeros_like(imgout)
    deltaE = deltaS.copy()
    NS = deltaS.copy()
    EW = deltaS.copy()
    gS = np.ones_like(imgout)
    gE = gS.copy()

    for ii in range(niter):
        deltaS[:-1, :] = np.diff(imgout, axis=0)
        deltaE[:, :-1] = np.diff(imgout, axis=1)
        if option == 1:
            gS = np.exp(-(deltaS/kappa)**2.)/step[0]
            gE = np.exp(-(deltaE/kappa)**2.)/step[1]
        elif option == 2:
            gS = 1./(1.+(deltaS/kappa)**2.)/step[0]
            gE = 1./(1.+(deltaE/kappa)**2.)/step[1]
        E = gE * deltaE
        S = gS * deltaS
        NS[:] = S
        EW[:] = E
        NS[1:, :] -= S[:-1, :]
        EW[:, 1:] -= E[:, :-1]
        imgout += gamma * (NS + EW)

    return imgout

# Directories setup
input_dir = './demo_datasets_week8'  # Your input dataset directory
output_dir = './Demo_Dataset(anisotropic_only)'  # Directory for processed images

# Create output directory if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Define supported image extensions including .tif and .tiff
supported_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.tif')

# Process each class folder and each image
for class_folder in os.listdir(input_dir):
    class_path = os.path.join(input_dir, class_folder)
    if not os.path.isdir(class_path):
        continue
    
    # Create corresponding class folder in the output directory
    output_class_path = os.path.join(output_dir, class_folder)
    if not os.path.exists(output_class_path):
        os.makedirs(output_class_path)
    
    # Process each image in the class folder
    for image_name in os.listdir(class_path):
        image_path = os.path.join(class_path, image_name)
        
        # Check if the file is an image by extension
        if not image_name.lower().endswith(supported_extensions):
            print(f"Skipping non-image file: {image_path}")
            continue
        
        # Load the image
        image = cv.imread(image_path, cv.IMREAD_UNCHANGED)
        if image is None:
            print(f"Failed to load image: {image_path}")
            continue
        
        # Convert to RGB if not already in correct format
        if len(image.shape) == 2 or image.shape[2] == 1:  # Handle grayscale images
            image = cv.cvtColor(image, cv.COLOR_GRAY2RGB)
        elif image.shape[2] == 4:  # Handle images with alpha channel
            image = cv.cvtColor(image, cv.COLOR_BGRA2RGB)
        else:
            image = cv.cvtColor(image, cv.COLOR_BGR2RGB)
        
        # Apply Anisotropic Diffusion
        diffused_image = anisodiff_color(image, niter=10, kappa=100, gamma=0.1, step=(1., 1.), option=1)
        
        # Rescale to [0, 255] and ensure type is uint8
        diffused_image = np.clip(diffused_image, 0, 255).astype(np.uint8)
        
        # Convert back to BGR for saving
        diffused_image_bgr = cv.cvtColor(diffused_image, cv.COLOR_RGB2BGR)
        
        # Save the processed image as JPEG or PNG
        output_image_path = os.path.join(output_class_path, image_name.replace('.tif', '.png'))  # Save as PNG or JPEG
        cv.imwrite(output_image_path, diffused_image_bgr)
        
        print(f"Processed and saved: {output_image_path}")
# Out:
# Processed and saved: ./Demo_Dataset(anisotropic_only)\ADI\1015_CRC-Prim-HE-10_020.png_Row_601_Col_601.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\ADI\1040C_CRC-Prim-HE-05_032.png_Row_1051_Col_2101.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\ADI\
.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-VAYIFTKH.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-VCFCFCYT.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-VCQNDRED.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-VCWGMSKH.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-VDGWMINV.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-VDNDKFCQ.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-VDQLWEDK.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-VDSLHNSN.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-VDYPFRWC.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-VEIQCVLH.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-VEPNETWL.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-VFRPSKNV.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-VGDWQPRT.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-VHIDGHGG.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-VIDIQHHY.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-VIMTFFAD.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-VKYFESEG.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-VLTDYMWK.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-VMESNKIL.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-VMPIWGWL.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-VNGVSVIY.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-VPNDRVPW.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-VPNHDPGG.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-VPPTHRHH.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-VPSWFNRH.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-VRTFQFEG.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-VRVMRTES.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-VSENPSMS.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-VSKFKGKI.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-VSRYTGPR.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-VTDCSIAM.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-VVEMNVTW.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-VWICRDTR.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-VWWSDSTA.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-VYGEAFND.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-WAELHYKM.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-WCKNELIR.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-WDDAVYAK.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-WDKEVKRE.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-WDRDDTIT.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-WFCCQQKI.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-WFILGPTM.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-WGATCDLC.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-WGGMVSHG.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-WHMGFIYN.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-WHRNYQWP.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-WIKAVAEN.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-WITHWLYA.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-WIYINRIY.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-WLFWCPRI.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-WLGCGQMC.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-WLYKAWDP.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-WMLYHGSE.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-WMRGFNIW.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-WMTPHVLF.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-WNFRNQYC.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-WNMVTHTE.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-WNPVRVVC.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-WNTRHTWS.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-WQGVGFEV.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-WQLDFQAT.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-WQYSFTAM.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-WSCQQFTR.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-WSVLPRYL.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-WTIDCRYE.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-WTRLSFIT.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-WTYDDTEG.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-WVFVWIMD.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-WVKQFELS.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-WWGMNGIY.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-WWNRFVAP.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-WWVNLKRS.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-WYEVFSCQ.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-WYKFRQAH.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-YAFVAPTG.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-YAKYKWCM.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-YAQWNGSD.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-YAVWITQP.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-YCDWISWK.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-YCNIWQGP.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-YCQFPRWT.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-YCRMARCA.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-YDCTKVHF.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-YDVHFEMT.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-YEAMDYHD.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-YETCYFAR.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-YFDLRLLR.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-YFHSQDSH.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-YFQQTMFE.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-YFQVFGHW.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-YGAPLFIE.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-YGQGYEGR.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-YHKPFYTM.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-YHWLMYND.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-YIEGVFEI.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-YIYVCGKQ.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-YKFQAAWL.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-YKHDFNVE.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-YLAVRGTV.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-YLDHDHKK.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-YLIYYSGP.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-YLTPIWTR.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-YLWCRHCL.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-YMVKLYEQ.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-YNNVMWSV.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-YPAHTAAA.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-YPLTGGLG.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-YQSIDIPN.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-YSCDFLMN.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-YVTTEEFY.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-YVVNSMTN.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-YYSSGWQM.png
# Processed and saved: ./Demo_Dataset(anisotropic_only)\TUM\TUM-YYWMMMNW.png

# %%
import os

# Define the path to the processed dataset directory
output_dir = './Demo_Dataset(anisotropic_only)'

# Initialize a dictionary to hold the counts for each class
class_counts = {}

# Iterate through each class folder in the output directory
for class_folder in os.listdir(output_dir):
    class_path = os.path.join(output_dir, class_folder)
    
    # Check if it is a directory
    if os.path.isdir(class_path):
        # Count the number of image files in the class folder
        num_images = len([img for img in os.listdir(class_path) if img.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.tif'))])
        class_counts[class_folder] = num_images

# Print the counts for each class
for class_name, count in class_counts.items():
    print(f"Class '{class_name}': {count} images")
# Out:
# Class 'ADI': 1000 images
# Class 'DEBRIS_MUCUS': 1000 images
# Class 'LYM': 1000 images
# Class 'MUSC_STROMA': 1000 images
# Class 'NORM': 1000 images
# Class 'TUM': 1000 images
